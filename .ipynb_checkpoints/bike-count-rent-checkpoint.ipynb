# %% [markdown]
# # Title- bike demand on rent #

# %% [markdown]
# ## Description ##

# %% [raw]
# this is a project in which we have to predict count of rented bike on daily basis. this prediction has to be done according to seasonal and environmental conditions.
#
# The details of data attributes in the dataset are as follows -
# instant   : Record index
# dteday    : Date
# season    : Season (1:springer, 2:summer, 3:fall, 4:winter)
# yr        : Year (0: 2011, 1:2012)
# mnth      : Month (1 to 12)
# hr        : Hour (0 to 23)
# holiday   : weather day is holiday or not (extracted fromHoliday Schedule)
# weekday   : Day of the week
# workingday: If day is neither weekend nor holiday is 1, otherwise is 0.
# weathersit: (extracted fromFreemeteo)
#
# 1: Clear, Few clouds, Partly cloudy, Partly cloudy
# 2: Mist + Cloudy, Mist + Broken clouds, Mist + Few clouds, Mist
# 3: Light Snow, Light Rain + Thunderstorm + Scattered clouds, Light Rain + Scattered
# clouds
# 4: Heavy Rain + Ice Pallets + Thunderstorm + Mist, Snow + Fog
#
# temp      : Normalized temperature in Celsius. The values are derived via
#             (t-t_min)/(t_max-t_min),
#             t_min=-8, t_max=+39 (only in hourly scale)
# atemp     : Normalized feeling temperature in Celsius. The values are derived via
#            (t-t_min)/(t_maxt_min), t_min=-16, t_max=+50 (only in hourly scale)
# hum       : Normalized humidity. The values are divided to 100 (max)
# windspeed : Normalized wind speed. The values are divided to 67 (max)
# casual    : count of casual users
# registered: count of reg

# %%
# load important library
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
# load dataset
df=pd.read_csv("bike-rent-data.csv",index_col=[0])

# %%
#summary of dataset
print(df.shape)
print("#"*50)
print(df.info())
print("#"*50)
print(df.describe())
# Out:
# (731, 15)
# ##################################################
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 731 entries, 1 to 731
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   dteday      731 non-null    object
#  1   season      731 non-null    int64
#  2   yr          731 non-null    int64
#  3   mnth        731 non-null    int64
#  4   holiday     731 non-null    int64
#  5   weekday     731 non-null    int64
#  6   workingday  731 non-null    int64
#  7   weathersit  731 non-null    int64
#  8   temp        731 non-null    float64
#  9   atemp       731 non-null    float64
#  10  hum         731 non-null    float64
#  11  windspeed   731 non-null    float64
#  12  casual      731 non-null    int64
#  13  registered  731 non-null    int64
#  14  cnt         731 non-null    int64
# dtypes: float64(4), int64(10), object(1)
# memory usage: 91.4+ KB
# None
# ...

# %% [raw]
# ### we have seen by analysing dataset that there is no missing value found in our dataset

# %% [markdown]
# ## outlier analysis ##

# %%
df.columns
# Out:
# Index(['dteday', 'season', 'yr', 'mnth', 'holiday', 'weekday', 'workingday',
#        'weathersit', 'temp', 'atemp', 'hum', 'windspeed', 'casual',
#        'registered', 'cnt'],
#       dtype='object')

# %%
df=df.rename(columns={'dteday':'date','yr':'year','mnth':'month','weathersit':'weather_condition','temp':'temperature','atemp':'feeling_temperature',
                     'hum':'humidity','cnt':'total_count'})

# %%
cnames = ['temperature', 'feeling_temperature', 'humidity', 'windspeed','total_count']

# %%
plt.figure(figsize=(16,9))
plt.subplot(221)
plt.boxplot(df['temperature'])
plt.subplot(222)
plt.boxplot(df['feeling_temperature'])
plt.subplot(223)
plt.boxplot(df['humidity'])
plt.subplot(224)
plt.boxplot(df['windspeed'])
plt.show()

# %% [raw]
# windspeed and humidity has some outliers.
# As we have only few obseravtion so we have to replace these values with nan values and then impute
# as missing values.

# %%
for i in cnames:
    
    q1,q3 = np.percentile(df.loc[:,i],[25,75])
    iqr = q3-q1
    min_q = q1 - 1.5*iqr
    max_q = q3 + 1.5*iqr
    df.loc[df[i]<min_q,i]=np.nan
    df.loc[df[i]>max_q,i]=np.nan

# %%
#now check outliers as missing values
df.isnull().sum()
# Out:
# date                    0
# season                  0
# year                    0
# month                   0
# holiday                 0
# weekday                 0
# workingday              0
# weather_condition       0
# temperature             0
# feeling_temperature     0
# humidity                2
# windspeed              13
# casual                  0
# registered              0
# total_count             0
# dtype: int64

# %%
#we have total 15 outliers as missing value
#fill these values by mean value
df.fillna(df.mean(),inplace=True)

# %%
df.to_csv("BikeRentDataProcessed.csv")

# %% [markdown]
# ## feature selection

# %% [raw]
# As we have all features in normalisation form, so they all have normal distribution

# %%
#corrplot
df_corr=df[cnames].corr()
plt.figure(figsize=(16,9))
sns.heatmap(df_corr,annot=True)
plt.title("Heatmap for correlation of numerical features")
# Out:
# Text(0.5, 1.0, 'Heatmap for correlation of numerical features')

# %% [raw]
# feeling_temperature and temperature are correlated so we consider only temperature for our model building.
# windspeed and humidity has less impact on total count as shown in heatmap.
# plot the scatter plot for humidity and windspeed against total_count

# %%
plt.figure(figsize=(16,9))
plt.scatter(df['temperature'],df['total_count'])
plt.title("Scatter plot for Total count and Temperature relationship")
plt.ylabel('Total Count')
plt.xlabel('Temperature')
# Out:
# Text(0.5, 0, 'Temperature')

# %%
plt.figure(figsize=(16,9))
plt.scatter(df['windspeed'],df['total_count'])
plt.title('scatter plot for windspeed')
plt.xlabel('windspeed')
plt.ylabel('total count')
# Out:
# Text(0, 0.5, 'total count')

# %%
plt.figure(figsize=(16,9))
plt.scatter(df['humidity'],df['total_count'])
plt.title('scatter plot for humidity')
plt.xlabel('Humidity')
plt.ylabel('total count')
# Out:
# Text(0, 0.5, 'total count')

# %% [raw]
# As we can see impact of windspeed and humidity on total count which is very less.
# colored points are for temperature which indicates sole impact on total count.

# %%
#impact of categorical data on total count
plt.figure(figsize=(16,9))
plt.subplot(421)
sns.barplot(df['season'],df['total_count'])
plt.subplot(422)
sns.barplot(df['year'],df['total_count'])
plt.subplot(423)
sns.barplot(df['month'],df['total_count'])
plt.subplot(424)
sns.barplot(df['holiday'],df['total_count'])
plt.subplot(425)
sns.barplot(df['workingday'],df['total_count'])
plt.subplot(426)
sns.barplot(df['weekday'],df['total_count'])
plt.subplot(427)
sns.barplot(df['weather_condition'],df['total_count'])

# %% [raw]
# from the above graph we can conclude that holiday, workingday and weekday have less impact on total_count,
# But season, month, year,weather_condition has a remarkable impact as in the hot season and months there is
# high demand with a good weather_condition.

# %%
# remove date, holiday, workingday, weekday, feeling_temperature,humidity,windspeed, casual and registered from the data set
df= df.drop(['date','workingday','weekday','feeling_temperature','humidity','windspeed','casual','registered'],axis=1)

# %%
print(df)
# Out:
#          season  year  month  holiday  weather_condition  temperature  \
# instant
# 1             1     0      1        0                  2     0.344167
# 2             1     0      1        0                  2     0.363478
# 3             1     0      1        0                  1     0.196364
# 4             1     0      1        0                  1     0.200000
# 5             1     0      1        0                  1     0.226957
# ...         ...   ...    ...      ...                ...          ...
# 727           1     1     12        0                  2     0.254167
# 728           1     1     12        0                  2     0.253333
# 729           1     1     12        0                  2     0.253333
# 730           1     1     12        0                  1     0.255833
# 731           1     1     12        0                  2     0.215833
#
#          total_count
# instant
# 1              985.0
# 2              801.0
# 3             1349.0
# ...

# %% [markdown]
# # model building

# %%
# import train_test_split
from sklearn.model_selection import train_test_split

#Divide data into train and test
X = df.values[:, 0:6]
Y = df.values[:,6]

X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.2)

# %% [markdown]
# ### linear regression

# %%
from sklearn.linear_model import LinearRegression

#create linear regression model
lr = LinearRegression()

# fit and train the model
lr = lr.fit(X_train, y_train)

# prediction using selected model
y_pred_lr = lr.predict(X_test)

# %%
## evaluation of linear model using r2 score
## r2 score
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_lr)
# Out:
# 0.8154337039840303

# %% [markdown]
# ### knn method|

# %%
from sklearn.neighbors import KNeighborsRegressor
#create model
knn = KNeighborsRegressor(n_neighbors=5)

#fit the model
knn = knn.fit(X_train, y_train)

#predictions
y_pred_knn = knn.predict(X_test)

# r2 score
from sklearn.metrics import r2_score
r2_score(y_test, y_pred_knn)
# Out:
# 0.8702736451603715

# %% [markdown]
# ### random forest

# %%
from sklearn.ensemble import RandomForestRegressor
#create rf model
rf = RandomForestRegressor(n_estimators=100)

#fit rf model
rf = rf.fit(X_train, y_train)

# prediction using rf
y_pred_rf = rf.predict(X_test)

# r2 score
r2_score(y_test, y_pred_rf)
# Out:
# 0.8786165422264344

# %% [raw]
# The best model for our problem is random forest based on r2 score.
